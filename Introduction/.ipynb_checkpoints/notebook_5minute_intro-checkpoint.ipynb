# %% [markdown]
# <h2>Introduction to Python</h2>
# <h3>Learn how read a file, shuffle data, filter data, plot data, split file into training and test sets</h3>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Modified IRIS Dataset - Introduced NaNs for some of the observations
# Dataset: https://archive.ics.uci.edu/ml/datasets/Iris/

# %%
df = pd.read_csv('IrisMissingData.csv')

# %%
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          NaN           1.4          0.3  Iris-setosa
# 7           5.0          3.4           NaN          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
df.loc[0:2] # First 3 Rows
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa

# %%
df.loc[7] # Specific Row
# Out:
# sepal_length              5
# sepal_width             3.4
# petal_length            NaN
# petal_width             0.2
# class           Iris-setosa
# Name: 7, dtype: object

# %%
df.shape
# Out:
# (150, 5)

# %%
df['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
# 5      5.4
# 6      4.6
# 7      5.0
# 8      4.4
# 9      4.9
# 10     5.4
# 11     4.8
# 12     4.8
# 13     4.3
# 14     5.8
# 15     5.7
# 16     5.4
# 17     5.1
# 18     5.7
# 19     5.1
# 20     5.4
# 21     5.1
# 22     4.6
# 23     5.1
# 24     4.8
# 25     5.0
# 26     5.0
# 27     5.2
# 28     5.2
# 29     4.7
#       ...
# 120    6.9
# 121    5.6
# 122    7.7
# 123    6.3
# 124    6.7
# 125    7.2
# 126    6.2
# 127    6.1
# 128    6.4
# 129    7.2
# 130    7.4
# 131    7.9
# 132    6.4
# 133    6.3
# 134    6.1
# 135    7.7
# 136    6.3
# 137    6.4
# 138    6.0
# 139    6.9
# 140    6.7
# 141    6.9
# 142    5.8
# 143    6.8
# 144    6.7
# 145    NaN
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df[['sepal_length','sepal_width']]
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# 5             5.4          3.9
# 6             4.6          NaN
# 7             5.0          3.4
# 8             4.4          2.9
# 9             4.9          3.1
# 10            5.4          3.7
# 11            4.8          3.4
# 12            4.8          3.0
# 13            4.3          3.0
# 14            5.8          4.0
# 15            5.7          4.4
# 16            5.4          3.9
# 17            5.1          3.5
# 18            5.7          3.8
# 19            5.1          3.8
# 20            5.4          3.4
# 21            5.1          3.7
# 22            4.6          3.6
# 23            5.1          3.3
# 24            4.8          3.4
# 25            5.0          3.0
# 26            5.0          3.4
# 27            5.2          3.5
# 28            5.2          3.4
# 29            4.7          3.2
# ..            ...          ...
# 120           6.9          3.2
# 121           5.6          2.8
# 122           7.7          2.8
# 123           6.3          2.7
# 124           6.7          3.3
# 125           7.2          3.2
# 126           6.2          2.8
# 127           6.1          NaN
# 128           6.4          2.8
# 129           7.2          3.0
# 130           7.4          2.8
# 131           7.9          3.8
# 132           6.4          2.8
# 133           6.3          2.8
# 134           6.1          2.6
# 135           7.7          3.0
# 136           6.3          3.4
# 137           6.4          3.1
# 138           6.0          3.0
# 139           6.9          3.1
# 140           6.7          3.1
# 141           6.9          3.1
# 142           5.8          2.7
# 143           6.8          3.2
# 144           6.7          3.3
# 145           NaN          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
df_1 = df[['sepal_length','sepal_width']]

# %%
df_1.ndim
# Out:
# 2

# %%
df_1.size
# Out:
# 300

# %%
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          NaN           1.4          0.3  Iris-setosa
# 7           5.0          3.4           NaN          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 145           NaN          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.mean()
# Out:
# sepal_length    5.836486
# sepal_width     3.056463
# petal_length    3.748630
# petal_width     1.205405
# dtype: float64

# %%
df = df.fillna(df.mean())

# %%
df.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 140      6.700000          3.1       3.74863          2.4  Iris-virginica
# 141      6.900000          3.1       5.10000          2.3  Iris-virginica
# 142      5.800000          2.7       5.10000          1.9  Iris-virginica
# 143      6.800000          3.2       5.90000          2.3  Iris-virginica
# 144      6.700000          3.3       5.70000          2.5  Iris-virginica
# 145      5.836486          3.0       5.20000          2.3  Iris-virginica
# 146      6.300000          2.5       5.00000          1.9  Iris-virginica
# 147      6.500000          3.0       5.20000          2.0  Iris-virginica
# 148      6.200000          3.4       5.40000          2.3  Iris-virginica
# 149      5.900000          3.0       5.10000          1.8  Iris-virginica

# %%
df.mean()
# Out:
# sepal_length    5.836486
# sepal_width     3.056463
# petal_length    3.748630
# petal_width     1.205405
# dtype: float64

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 145      5.836486          3.0           5.2          2.3  Iris-virginica
# 146      6.300000          2.5           5.0          1.9  Iris-virginica
# 147      6.500000          3.0           5.2          2.0  Iris-virginica
# 148      6.200000          3.4           5.4          2.3  Iris-virginica
# 149      5.900000          3.0           5.1          1.8  Iris-virginica

# %%
df.shape # returns a tupple (no. of rows, no. of column)
# Out:
# (150, 5)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
# Print first 5 index values and last 5 index values
index_list = list(df.index)
print(index_list[:5])
print(index_list[-5:])
# Out:
# [0, 1, 2, 3, 4]
# [145, 146, 147, 148, 149]

# %%
# Randomize a list
np.random.seed(5)
np.random.shuffle(index_list)

# %%
print('Shuffled list')
print(index_list[:5])
print(index_list[-5:])
# Out:
# Shuffled list
# [82, 134, 114, 42, 109]
# [8, 73, 144, 118, 99]

# %%
df.loc[3:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa

# %%
df.iloc[3:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Dataframe is now shuffled
df = df.iloc[index_list]

# %%
df.head(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 82            5.8          2.7           3.9          1.2  Iris-versicolor
# 134           6.1          2.6           5.6          1.4   Iris-virginica
# 114           5.8          2.8           5.1          2.4   Iris-virginica
# 42            4.4          3.2           1.3          0.2      Iris-setosa
# 109           7.2          3.6           6.1          2.5   Iris-virginica
# 57            4.9          2.4           3.3          1.0  Iris-versicolor
# 1             4.9          3.0           1.4          0.2      Iris-setosa
# 70            5.9          3.2           4.8          1.8  Iris-versicolor
# 25            5.0          3.0           1.6          0.2      Iris-setosa
# 84            5.4          3.0           4.5          1.5  Iris-versicolor

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 8             4.4          2.9           1.4          0.2      Iris-setosa
# 73            6.1          2.8           4.7          1.2  Iris-versicolor
# 144           6.7          3.3           5.7          2.5   Iris-virginica
# 118           7.7          2.6           6.9          2.3   Iris-virginica
# 99            5.7          2.8           4.1          1.3  Iris-versicolor

# %%
df.shape
# Out:
# (150, 5)

# %%
df.size
# Out:
# 750

# %%
# Split data into training and test sets
# training = 70%
# test = 30%
size = df.shape[0]
train = round(size *.7)
test = size - train

# %%
size, train, test
# Out:
# (150, 105, 45)

# %%
df[:train].to_csv('iris_data_train.csv',index=True,index_label='Row',
columns=['sepal_length','sepal_width','petal_length','petal_width','class'])

# %%
df[train:].to_csv('iris_data_test.csv',index=True,index_label='Row',
          columns=['sepal_length','sepal_width','petal_length','petal_width'])

# %%
df['class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: class, dtype: int64

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.836486     3.056463      3.748630     1.205405
# std        0.824959     0.429307      1.741643     0.757759
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.250000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 82            5.8          2.7           3.9          1.2  Iris-versicolor
# 134           6.1          2.6           5.6          1.4   Iris-virginica
# 114           5.8          2.8           5.1          2.4   Iris-virginica
# 42            4.4          3.2           1.3          0.2      Iris-setosa
# 109           7.2          3.6           6.1          2.5   Iris-virginica

# %%
# Find all rows that match the condition.  Returns a Series that contains index value and True/False

df[df["class"] == "Iris-setosa"]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 42           4.4     3.200000       1.30000     0.200000  Iris-setosa
# 1            4.9     3.000000       1.40000     0.200000  Iris-setosa
# 25           5.0     3.000000       1.60000     0.200000  Iris-setosa
# 26           5.0     3.400000       1.60000     0.400000  Iris-setosa
# 23           5.1     3.300000       1.70000     0.500000  Iris-setosa
# 21           5.1     3.700000       1.50000     0.400000  Iris-setosa
# 12           4.8     3.000000       1.40000     1.205405  Iris-setosa
# 48           5.3     3.700000       1.50000     0.200000  Iris-setosa
# 39           5.1     3.400000       1.50000     0.200000  Iris-setosa
# 10           5.4     3.700000       1.50000     0.200000  Iris-setosa
# 49           5.0     3.300000       1.40000     0.200000  Iris-setosa
# 43           5.0     3.500000       1.60000     0.600000  Iris-setosa
# 40           5.0     3.500000       1.30000     0.300000  Iris-setosa
# 17           5.1     3.500000       1.40000     0.300000  Iris-setosa
# 46           5.1     3.800000       1.60000     0.200000  Iris-setosa
# 20           5.4     3.400000       1.70000     0.200000  Iris-setosa
# 35           5.0     3.200000       1.20000     0.200000  Iris-setosa
# 6            4.6     3.056463       1.40000     0.300000  Iris-setosa
# 15           5.7     4.400000       1.50000     0.400000  Iris-setosa
# 28           5.2     3.400000       1.40000     0.200000  Iris-setosa
# 22           4.6     3.600000       1.00000     0.200000  Iris-setosa
# 37           4.9     3.100000       1.50000     0.100000  Iris-setosa
# 32           5.2     4.100000       1.50000     0.100000  Iris-setosa
# 13           4.3     3.000000       1.10000     0.100000  Iris-setosa
# 24           4.8     3.400000       1.90000     0.200000  Iris-setosa
# 45           4.8     3.000000       1.40000     0.300000  Iris-setosa
# 34           4.9     3.100000       1.50000     0.100000  Iris-setosa
# 47           4.6     3.200000       1.40000     0.200000  Iris-setosa
# 9            4.9     3.100000       1.50000     0.100000  Iris-setosa
# 14           5.8     4.000000       1.20000     0.200000  Iris-setosa
# 16           5.4     3.900000       1.30000     0.400000  Iris-setosa
# 33           5.5     4.200000       1.40000     0.200000  Iris-setosa
# 29           4.7     3.200000       1.60000     0.200000  Iris-setosa
# 3            4.6     3.100000       1.50000     0.200000  Iris-setosa
# 11           4.8     3.400000       1.60000     0.200000  Iris-setosa
# 18           5.7     3.800000       1.70000     0.300000  Iris-setosa
# 19           5.1     3.800000       1.50000     0.300000  Iris-setosa
# 38           4.4     3.000000       1.30000     0.200000  Iris-setosa
# 2            4.7     3.200000       1.30000     0.200000  Iris-setosa
# 31           5.4     3.400000       1.50000     0.400000  Iris-setosa
# 36           5.5     3.500000       1.30000     0.200000  Iris-setosa
# 4            5.0     3.600000       1.40000     0.200000  Iris-setosa
# 0            5.1     3.500000       1.40000     0.200000  Iris-setosa
# 5            5.4     3.900000       1.70000     0.400000  Iris-setosa
# 41           4.5     2.300000       1.30000     0.300000  Iris-setosa
# 30           4.8     3.100000       1.60000     0.200000  Iris-setosa
# 44           5.1     3.800000       1.90000     0.400000  Iris-setosa
# 27           5.2     3.500000       1.50000     0.200000  Iris-setosa
# 7            5.0     3.400000       3.74863     0.200000  Iris-setosa
# 8            4.4     2.900000       1.40000     0.200000  Iris-setosa

# %%
# Find all rows that match the condition.  Returns a Series that contains index value and True/False
setosa = df['class'] == 'Iris-setosa'

# %%
setosa.head()
# Out:
# 82     False
# 134    False
# 114    False
# 42      True
# 109    False
# Name: class, dtype: bool

# %%
# Pull only setosa's
df[setosa].head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 42           4.4          3.2           1.3          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 25           5.0          3.0           1.6          0.2  Iris-setosa
# 26           5.0          3.4           1.6          0.4  Iris-setosa
# 23           5.1          3.3           1.7          0.5  Iris-setosa

# %%
plt.hist(df.petal_length)
plt.grid(True)
plt.xlabel('Petal Length')
plt.ylabel('Count')
plt.title('Petal Length Histogram')
# Out:
# Text(0.5, 1.0, 'Petal Length Histogram')

# %%
plt.hist(df.petal_width)

plt.grid(True)
plt.xlabel("Petal Width")
plt.ylabel("Count")
plt.title("Petal Width Histogram")
# Out:
# Text(0.5, 1.0, 'Petal Width Histogram')

# %%
plt.scatter(df.index, df.petal_length)

plt.grid(True)
plt.xlabel('Sample') 
plt.ylabel('Petal Length')
plt.title('Petal Length Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Petal Length Scatter Plot')

# %%
versicolor = df['class'] == "Iris-versicolor"
virginica = df['class'] == "Iris-virginica"

# %%
plt.scatter(df[setosa].index, df[setosa].petal_length, label ='setosa')
plt.scatter(df[versicolor].index, df[versicolor].petal_length, label = 'versicolor')
plt.scatter(df[virginica].index, df[virginica].petal_length, label = 'virginica')
plt.grid(True)
plt.xlabel('Sample') 
plt.ylabel('Petal Length')
plt.title('Petal Length Scatter Plot')
plt.legend()
